# %% [markdown]
# # can pandas handles missing values in a datase ?
# yes

# %% [markdown]
# ## is numPy mainlyused for numerical and array-based computation yes

# %% [markdown]
# ## can python be used to analyze large datasets efficiently?
# yes

# %% [markdown]
# # is Matplotlib used for data visualization? ->yes

# %% [markdown]
# # can pandas read data from Excel and csv files ->yes

# %% [markdown]
# # is SQL mandatory to perform data analysis in python -> no

# %% [markdown]
# # Does DataFrame.describe() provides summary statistics of numerical columns? ->yes

# %% [markdown]
# # can missing data be handled using dropna() and fillna()in pandas?-> yes

# %% [markdown]
# # is Seaborn built on top of Matplotlib?-> yes

# %% [markdown]
# # can python be usedfor both data analysis and machine learning ? ->yes

# %%
import numpy as np
import pandas as pd

# %%
patient_df = pd.read_csv("/Users/michelkadi/machinelearning/sample-patients-prom/input_files/csv/Encounter.csv")
print(patient_df.head())
# Out:
#                                  Id                    status     Class       \
# 0
# 1                                    # Hip Resources        NaN          NaN
# 2  # -----------------+---------+-----------+----...        NaN          NaN
# 3  #  ID              | status  | class     | Pat...        NaN          NaN
# 4  #  0               | 1       | 2         | 3  ...        NaN          NaN
#
#     Patient                                       Period                       \
# 0   Reference                Display              Start           End
# 1                      NaN                  NaN             NaN           NaN
# 2                      NaN                  NaN             NaN           NaN
# 3                      NaN                  NaN             NaN           NaN
# 4                      NaN                  NaN             NaN           NaN
#
#     Type                                                    \
# 0   System               Code        Display
# ...

# %% [markdown]
# https://youtu.be/GNef5Vc5Dhw?t=1266
