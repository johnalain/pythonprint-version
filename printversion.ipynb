# %%
import sys
print('python: {}'.format(sys.version))

import scipy
print('scipy: {}'.format(scipy.__version__))

import numpy
print('numpy: {}'.format(numpy.__version__))

import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))

import pandas
print('pandas: {}'.format(pandas.__version__))

#install scikit-learn instead of sklearn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
"""
python: 3.12.9 (v3.12.9:fdb81425a9a, Feb  4 2025, 12:21:36) [Clang 13.0.0 (clang-1300.0.29.30)]
scipy: 1.13.0
numpy: 1.26.4
matplotlib: 3.10.8
pandas: 2.2.1
sklearn: 1.8.0
"""
# Out:
# python: 3.12.9 (v3.12.9:fdb81425a9a, Feb  4 2025, 12:21:36) [Clang 13.0.0 (clang-1300.0.29.30)]
# scipy: 1.13.0
# numpy: 1.26.4
# matplotlib: 3.10.8
# pandas: 2.2.1
# sklearn: 1.8.0
# '\npython: 3.12.9 (v3.12.9:fdb81425a9a, Feb  4 2025, 12:21:36) [Clang 13.0.0 (clang-1300.0.29.30)]\nscipy: 1.13.0\nnumpy: 1.26.4\nmatplotlib: 3.10.8\npandas: 2.2.1\nsklearn: 1.8.0\n'

# %%
import sys
import scipy
import numpy
import matplotlib

print(f'python: {sys.version}')
print(f'scipy: {scipy.__version__}')
print(f'numpy: {numpy.__version__}')
print(f'matplotlib: {matplotlib.__version__}')
# Out:
# python: 3.12.9 (v3.12.9:fdb81425a9a, Feb  4 2025, 12:21:36) [Clang 13.0.0 (clang-1300.0.29.30)]
# scipy: 1.13.0
# numpy: 1.26.4
# matplotlib: 3.10.8

# %% [markdown]
# https://youtu.be/N5fSpaaxoZc?t=2875

# %% [markdown]
# echo "# pythonprint-version" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/johnalain/pythonprint-version.git
# git push -u origin main
